# %% [markdown]
# # **Introducción Python**

# %% [markdown]
# ![Logo de Python](https://logos-world.net/wp-content/uploads/2021/10/Python-Logo.png)

# %% [markdown]
#  **Autor:**
# *Romulo Salvador* & *Semillero de Investigación en Business Analytics (SYBA UNALM)*
# **GitHub:** https://github.com/Romulo-Salvador
# **LinkedIn:** https://www.linkedin.com/in/romulo-salvador/
# **ORCID:** https://orcid.org/0009-0000-7998-1611

# %% [markdown]
# ### Índice
#
# #### 1. Introducción a Python
# Usos y aplicaciones de Python. Áreas de desarrollo destacadas. Entornos de trabajo (PyCharm, Jupyter, Azure, Colab)
#
# #### 2. Google Colab
# Atajos básicos. Tipos de celdas: Código y Markdown
#
# #### 3. Tipos de datos y variables
# 3.1. Numéricos (int, float)
# 3.2. Booleanos
# 3.3. Cadenas de texto (strings Y entrada de usuario)
#
# #### 4. Operadores
# 4.1. Aritméticos
# 4.2. Comparación (orden lexicográfico)
# 4.3. Lógicos
# 4.4. Asignación
# 4.5. Identidad
# 4.6. Pertenencia
#
# #### 5. Estructuras de control
# 5.1. Condicionales: if, elif, else
# 5.2. Bucles: for, while
#
# #### 6. Estructuras de datos
# 6.1. Listas
# 6.2. Matrices
# 6.3. Cadenas de caracteres
# 6.4. Tuplas
# 6.5. Conjuntos
# 6.6. Diccionarios
#
# #### 7. Funciones y control de flujo
# 7.1. break
# 7.2. continue
# 7.3. range
# 7.4. pass
# 7.5. Definición de funciones (def, return, parámetros por defecto)
# 7.6. Funciones lambda y composición
#
# #### 8. Clases y objetos
# 8.1. Definición de clases
# 8.2. Creación de objetos
# 8.3. Métodos de objetos

# %% [markdown]
# ### 1. Introducción a Python

# %% [markdown]
# Python se destaca por su versatilidad y amplia comunidad, lo que permite crear aplicaciones robustas para backend, automatización y análisis avanzado. Además, es muy usado en ciencia de datos, inteligencia artificial, ciberseguridad y desarrollo de herramientas multiplataforma.
#
# **Desarrollos interesantes en el mundo de Python:**
# * PyPI: El sistema de paquetes de Python, PyPI, ha superado los 200 millones de descargas al mes, lo que lo convierte en uno de los repositorios de paquetes más populares en el mundo.
#
# * Aplicaciones en la nube: Python está ganando terreno como lenguaje de elección para la implementación de aplicaciones en la nube, gracias a su amplia gama de bibliotecas y herramientas de desarrollo.
#
# * Científico de datos: Python sigue siendo un lenguaje popular para la ciencia de datos, con una creciente comunidad de usuarios que utilizan bibliotecas como NumPy, Pandas y Matplotlib para analizar y visualizar grandes conjuntos de datos.
#
# * Automatización: Python también es ampliamente utilizado en la automatización de tareas, especialmente en áreas como la automatización de pruebas, la gestión de redes y la automatización de trabajos en segundo plano.
#
# **Entornos de trabajo para Python:**
# * PyCharm
# * Jupyter Notebooks
# * Azure Notebooks
# * Google Collaboratory

# %% [markdown]
# ### 2. Introducción a Colab

# %% [markdown]
# **Atajos:**
#
# `Ctrl + m + a` Crear una celda sobre la actual
#
# `Ctrl + m + b` Crear una celda debajo de la actual
#
# `Ctrl + m + d` Borrar celda

# %% [markdown]
# #### 2.1. Tipos de celdas
#
# Para la ejecución de código en celdas se puede usar el botón play o la combinación de teclas `Shift + Enter`

# %%
print("Esto es una celda de código")
# Out:
# Esto es una celda de código

# %%
#Esto es un comentario en una celda de código
5 + 4
# Out:
# 9

# %% [markdown]
# ```
# Las siguiente son inputs y outputs en celdas Markdown
# ```
# Las siguiente son inputs y outputs en celdas Markdown
#
# ```
# # Esto es un título 1
# ```
# # Esto es un título 1
#
# ```
# ## Esto es un título 2
# ```
# ## Esto es un título 2
#
# ```
# ### Esto es un título 3
# ```
# ### Esto es un título 3
#
# ```
# *Esto es un texto en cursiva*
# ```
# *Esto es un texto en cursiva*
#
# ```
# **Esto es un texto en negrita**
# ```
# **Esto es un texto en negrita**
#
# ```
# Esto es una lista:
# 1.   Elemento de la lista
# 2.   Elemento de la lista
# ```
# Esto es una lista:
# 1.   Elemento de la lista
# 2.   Elemento de la lista

# %% [markdown]
# ### 3. Tipos de datos y variables
# A diferencia de otros lenguajes de programación, Python no requiere que se declaren los tipos de datos

# %% [markdown]
# #### 3.1. Numéricas

# %%
32
# Out:
# 32

# %%
# La ejecución solo muestra el último comando
x=32
print(x) #Si usamos comandos print se muestran varias filas de resultados
x
# Out:
# 32
# 32

# %%
#tipo de variable
type(x)
# Out:
# int

# %%
y = 45.0
type(y)
# Out:
# float

# %%
z = int(y)
print(z)
type(z)
# Out:
# 45
# int

# %%
y = 45.9
int(y) # solo toma en cuenta la parte entera, función SUELO
# Out:
# 45

# %%
#Impresion de varios valores en una sola linea de codigo
x, y, z
# Out:
# (32, 45.9, 45)

# %% [markdown]
# #### 3.2. Booleanos

# %%
a = True
b = False
print(a)
b
# Out:
# True
# False

# %%
int(a)
# Out:
# 1

# %%
float(b)
# Out:
# 0.0

# %% [markdown]
# #### 3.3. Cadenas

# %%
cadena = "Hola, mundo!"
cadena
# Out:
# 'Hola, mundo!'

# %%
type(cadena)
# Out:
# str

# %%
'Hola, "Alejandro" es mi nombre'
# Out:
# 'Hola, "Alejandro" es mi nombre'

# %%
"Hola, 'Manuel' es mi nombre"
# Out:
# "Hola, 'Manuel' es mi nombre"

# %% [markdown]
# #### Entrada de valores por usuario

# %%
nombre = input()
# Out:
# Romulo

# %%
nombre*5
# Out:
# 'RomuloRomuloRomuloRomuloRomulo'

# %%
saludo = "Hola, " + nombre
saludo
# Out:
# 'Hola, Romulo'

# %%
"python" + str(3)
# Out:
# 'python3'

# %%
saludo.lower()
# Out:
# 'hola, romulo'

# %%
saludo.upper()
# Out:
# 'HOLA, ROMULO'

# %%
saludo = saludo.upper()
saludo
# Out:
# 'HOLA, ROMULO'

# %%
"Natalia Malaga" == "natalia malaga"
# Out:
# False

# %% [markdown]
# ### 4. Operadores

# %% [markdown]
# #### 4.1. Operadores Aritméticos

# %% [markdown]
# *Adición*

# %%
# ¿Cuánto dura un partido de fútbol con tiempo extra?
45 + 45 + 15 + 15
# Out:
# 120

# %% [markdown]
# *Multiplicación*

# %%
# ¿Cuántos segundos tiene un día?
segundos = 24 * 60 * 60
segundos
# Out:
# 86400

# %% [markdown]
# *División*

# %%
47 / 9
# Out:
# 5.222222222222222

# %% [markdown]
# *División entera*

# %%
int(47/9)
# Out:
# 5

# %%
47 // 9
# Out:
# 5

# %% [markdown]
# *Residuo de una división*

# %%
47 % 9
# Out:
# 2

# %% [markdown]
# *Potencia*

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# *Raíz cuadrada*

# %%
16 ** (1/2)
# Out:
# 4.0

# %% [markdown]
# *Paréntesis para orden de operaciones*

# %%
4 + 5 * 6
# Out:
# 34

# %%
(4 + 5) * 6
# Out:
# 54

# %%
4 < 5
# Out:
# True

# %% [markdown]
# #### 4.2. Operadores  de Comparación

# %% [markdown]
# *Igualdad*

# %%
8==(2*4)
# Out:
# True

# %% [markdown]
# *Desigualdad*

# %%
8!=5
# Out:
# True

# %% [markdown]
# *Menor*

# %%
3<4
# Out:
# True

# %% [markdown]
# *Menor o igual que*

# %%
4<=4
# Out:
# True

# %%
3<=5
# Out:
# True

# %% [markdown]
# *Mayor*

# %%
8>4
# Out:
# True

# %% [markdown]
# *Mayor o igual que*

# %%
4>=4
# Out:
# True

# %%
6>=3
# Out:
# True

# %% [markdown]
# #### El orden lexicográfico
#
# Es el orden en el que se colocan las palabras en un diccionario. En Python, el orden lexicográfico se aplica a los objetos de tipo string, que se comparan carácter por carácter. Si un carácter en una cadena es menor que otro en otra cadena, la primera cadena es considerada menor que la segunda.

# %%
print("apple" < "banana")
print("cat" < "dog")
print("egg" < "eggs")

print("Zebra" < "apple")
print("apple" < "Apple")
# Out:
# True
# True
# True
# True
# False

# %% [markdown]
# El orden lexicográfico en Python es sensible a mayúsculas y minúsculas, por lo que las cadenas que contienen letras mayúsculas se colocan antes que las que contienen solo letras minúsculas. Es importante tener en cuenta que en Python, el orden lexicográfico se aplica a todos los tipos de secuencias, incluyendo listas, tuplas y conjuntos, y no solo a las cadenas.

# %% [markdown]
# #### 4.3. Operadores Lógicos

# %%
a=True
b=False

# %% [markdown]
# *And*

# %%
a and a
# Out:
# True

# %%
a and b
# Out:
# False

# %% [markdown]
# *Or*

# %%
a or b
# Out:
# True

# %%
# xor
a ^ b
# Out:
# True

# %% [markdown]
# *Not*

# %%
not a
# Out:
# False

# %% [markdown]
# Lógica proposicional

# %%
not((True and False) or (False and True))
# Out:
# True

# %% [markdown]
# #### 4.4. Operadores de Asignación

# %% [markdown]
# *Asignación simple*

# %%
x = 10
x
# Out:
# 10

# %% [markdown]
# *Asignación múltiple*

# %%
x = y = z = 10
x, y, z
# Out:
# (10, 10, 10)

# %% [markdown]
# *Adición de asignación*

# %%
x += 10
x
# Out:
# 20

# %% [markdown]
# *Sustracción de asignación*

# %%
x -= 10
x
# Out:
# 10

# %% [markdown]
# *Multiplicación de asignación*

# %%
x *= 10
x
# Out:
# 100

# %% [markdown]
# *División de asignación*

# %%
x /= 10
x
# Out:
# 10.0

# %% [markdown]
# *Módulo de asignación*

# %%
x %= 10
x
# Out:
# 0.0

# %% [markdown]
# *Potencia de asignación*

# %%
x **= 10
x
# Out:
# 0.0

# %% [markdown]
# *División entera de asignación*

# %%
x //= 10
x
# Out:
# 0.0

# %% [markdown]
# Además, en Python también es posible utilizar la asignación condicional con el operador ternario: *if-else*

# %%
x = 5 if y > 5 else 20
x
# Out:
# 5

# %% [markdown]
# #### 4.5. Operaciones de Identidad

# %% [markdown]
# *Is*

# %%
x = [1, 2, 3]
y = x
x is y
# Out:
# True

# %%
x = [1, 2, 3]
y = [1, 2, 3]
x is not y
# Out:
# True

# %% [markdown]
# Es importante tener en cuenta que los operadores de identidad se utilizan para comparar objetos en memoria y no valores. Por lo tanto, dos objetos que contienen los mismos valores pueden ser objetos diferentes en memoria.

# %%
x = [1, 2, 3]
y = [1, 2, 3]
x == y, x is y
# Out:
# (True, False)

# %% [markdown]
# #### 4.6. OPERADORES DE PERTENENCIA

# %% [markdown]
# *In*

# %%
x = [1, 2, 3]
2 in x
# Out:
# True

# %%
4 not in x
# Out:
# True

# %% [markdown]
# Estos operadores se pueden utilizar con diferentes tipos de objetos, como listas, tuplas, conjuntos, diccionarios, etc.

# %%
x = {'a': 1, 'b': 2}
'a' in x
# Out:
# True

# %% [markdown]
# ### 5. Estructuras de Control

# %% [markdown]
# #### 5.1. Condicionales

# %% [markdown]
# ##### 5.1.1. If

# %%
a = 33
b = 200
if b > a:
  print("b es mayor que a")
# Out:
# b es mayor que a

# %% [markdown]
# ##### 5.1.2. Elif

# %%
a = 33
b = 33
if b > a:
  print("b es mayor que a")
elif a == b:
  print("a y b son iguales")
# Out:
# a y b son iguales

# %% [markdown]
# ##### 5.1.3. Else

# %%
a = 200
b = 33
if b > a:
  print("b es mayor que a")
elif a == b:
  print("a y b son iguales")
else:
  print("a es mayor que b")
# Out:
# a es mayor que b

# %% [markdown]
# #### 5.2. Iterativas

# %% [markdown]
# #####  5.2.1. For

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ##### 5.2.2. While

# %%
i = 1
while i < 6:
  print(i) # mientras i es menor que 6, se imprime
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### 6. Estructuras de Datos

# %% [markdown]
# #### 6.1. Listas

# %%
lista=[3,2,1,3]
lista
# Out:
# [3, 2, 1, 3]

# %%
type(lista) # tipo de estructura
# Out:
# list

# %%
len(lista) # longitud o numero de elementos
# Out:
# 4

# %%
lista[0] # llamar un elemento
# Out:
# 3

# %%
lista[1:] # llamar un intervalo[cerrado:abierto]
# Out:
# [2, 1, 3]

# %%
lista.sort() # ordenar la lista
lista
# Out:
# [1, 2, 3, 3]

# %%
lista.sort(reverse=True) # ordenar la lista de forma descendente
lista
# Out:
# [3, 3, 2, 1]

# %%
lista.index(3) # imprime la posicion de 3, solo el mas cercano
# Out:
# 0

# %%
lista.count(3) # imprime las veces que esta repetido n
# Out:
# 2

# %%
2 in lista # imprime un booleano indicando si esta en la lista
# Out:
# True

# %%
lista.reverse() #inviertes el orden de la lista
lista
# Out:
# [1, 2, 3, 3]

# %% [markdown]
# **Modificar elementos de listas**

# %%
c2 = [i**2 for i in lista] # numeros al cuadrado
c2
# Out:
# [1, 4, 9, 9]

# %%
lista[2] = "Scala"
lista
# Out:
# [1, 2, 'Scala', 3]

# %% [markdown]
# **Aumentar elementos**

# %%
lista*3 # triplica len(lista)
# Out:
# [1, 2, 'Scala', 3, 1, 2, 'Scala', 3, 1, 2, 'Scala', 3]

# %%
lista.append(3) # agregar al final, ID constante
lista
# Out:
# [1, 2, 'Scala', 3, 3]

# %%
lista = lista + [3] # ID diferente
lista
# Out:
# [1, 2, 'Scala', 3, 3, 3]

# %%
lista.extend([7,8,9]) # agregar varios
lista
# Out:
# [1, 2, 'Scala', 3, 3, 3, 7, 8, 9]

# %%
lista.insert(0,20) # insertar "(posicion, valor)"
lista
# Out:
# [20, 1, 2, 'Scala', 3, 3, 3, 7, 8, 9]

# %% [markdown]
# **Eliminar elementos**

# %%
del lista [-1]
lista
# Out:
# [20, 1, 2, 'Scala', 3, 3, 3, 7, 8]

# %%
lista.pop(0) # borrar la posocion 0, default -1
# Out:
# 20

# %%
lista.remove(3) # elimina el valor indicado, solo una vez, la primera coincidencia
lista
# Out:
# [1, 2, 'Scala', 3, 3, 7, 8]

# %%
lista.clear() # elimina todos los valores de la lista
lista
# Out:
# []

# %%
lista1 = lista.copy() # diferente ID
print(id(lista))
id(lista1)
# Out:
# 138915332708928
# 138915332546112

# %%
lista2 = lista # igual ID
print(id(lista))
id(lista2)
# Out:
# 138915332708928
# 138915332708928

# %% [markdown]
# #### 6.2. Matrices

# %%
matriz= [[1,2],[3,4]]
matriz[0][1]
# Out:
# 2

# %%
matriz[1:][0:] # (matriz[1:])[:1]
# Out:
# [[3, 4]]

# %%
[lista]*3 # crea una matriz,igual ID
# Out:
# [[], [], []]

# %% [markdown]
# Otra forma de crear matrices:

# %%
notas=[]
x=3
for i in range(x): # x filas
    notas.append([0]*x) # x columnas, ID diferente
notas
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %% [markdown]
# Entrada de valores de una matriz

# %%
f=int(input("ingrese el número de filas: "))
c=int(input("ingrese el número de columnas: "))
notas=[]
for i in range(0,f):
    notas.append([0]*c)
print(notas)
for i in range(f):
    for j in range(c):
        print("ingrese la nota del ",i+1,"-ésimo estudiantes y del ",j+1,"-ésimo curso:")
        #nota =float(input())
        notas[i][j] = float(input())
print(notas)
# Out:
# ingrese el número de filas: 3
# ingrese el número de columnas: 2
# [[0, 0], [0, 0], [0, 0]]
# ingrese la nota del  1 -ésimo estudiantes y del  1 -ésimo curso:
# 15
# ingrese la nota del  1 -ésimo estudiantes y del  2 -ésimo curso:
# 13
# ingrese la nota del  2 -ésimo estudiantes y del  1 -ésimo curso:
# 11
# ingrese la nota del  2 -ésimo estudiantes y del  2 -ésimo curso:
# 17
# ingrese la nota del  3 -ésimo estudiantes y del  1 -ésimo curso:
# 18
# ingrese la nota del  3 -ésimo estudiantes y del  2 -ésimo curso:
# 12
# [[15.0, 13.0], [11.0, 17.0], [18.0, 12.0]]

# %% [markdown]
# #### 6.3. Cadena de Caracteres (inmutable)

# %%
# la cadena se comporta como una lista
cad= "hola mundo" # creando cadena
cad[0] # imprime la posicion 0 de la cadena
# Out:
# 'h'

# %%
cad[-1]
# Out:
# 'o'

# %%
cad[2:9]
# Out:
# 'la mund'

# %%
list(cad)
# Out:
# ['h', 'o', 'l', 'a', ' ', 'm', 'u', 'n', 'd', 'o']

# %%
cad + 's' # concatenando
# Out:
# 'hola mundos'

# %%
cad.replace('h','o') # reemplazamos 'h' por 'o'
# Out:
# 'oola mundo'

# %%
cad.upper() # la convierte a mayusculas
# Out:
# 'HOLA MUNDO'

# %%
for elem in cad: # cad se comporta como un range
  print(elem)
# Out:
# h
# o
# l
# a
#
# m
# u
# n
# d
# o

# %%
# k toma los valores [longitud,-1>, sumando -1(default:+1)
for k in range(len(cad)-1,-1,-1):
  print(cad[k])
# Out:
# o
# d
# n
# u
# m
#
# a
# l
# o
# h

# %% [markdown]
# #### 6.4. Tuplas

# %%
#La tupla es como una lista pero que no puede ser editada
tupla=(4,5,8,"contenido","elemento", [1,2,3],6.9) #creacion de tuplas
#los mismos codigos de lista funcionan con la tupla(*claro, cumplan la condicion de no ser editadas*)
lista = list(tupla) # conviertes la tupla en una lista
tupla = tuple(lista) #conviertes la lista en una tupla

# %% [markdown]
# #### 6.5. Conjuntos

# %%
conjunto =set() #si no ponemos esto python lo toma como un diccionario
conjunto = {1,2,"letter", 4.21} # al hacer esos dos pasos tenemos un conjunto
#en un cunjunto puede ir cualquier valor menos otras colecciones
conjunto.add(5) #agrega el valor indicado en cualquier lugar del conjunto
conjunto
# Out:
# {1, 2, 4.21, 5, 'letter'}

# %%
conjunto.discard(1) #elimina el valor indicado del conjunto
conjunto
# Out:
# {2, 4.21, 5, 'letter'}

# %%
conjunto.clear() #borra todos los elementos del conjunto
conjunto
# Out:
# set()

# %%
3 in conjunto # verifica si el valor indicado esta en el cojunto
# Out:
# False

# %%
3 not in conjunto #verifica si el valor indicado no esta en el cojunto
# Out:
# True

# %% [markdown]
# Operaciones con conjuntos (dados los conjuntos a y b)

# %%
a =set()
a = {1,2,3,4,5}
b =set()
b = {4,5,6,7,8}

# %%
c = a | b # al hacer eso unes dos conjuntos
c
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
c = a & b # intereseccion de conjuntos
c
# Out:
# {4, 5}

# %%
c = a - b # todo a menos b
c
# Out:
# {1, 2, 3}

# %%
c = a ^ b # diferencia simetrica
c
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
a.issubset(c) # verifica si a es un subconjunto de c
# Out:
# False

# %%
c.issuperset(a) #verifica si c es un superconjunto de a
# Out:
# False

# %%
a.isdisjoint(b) #verifica si a y b son disconjuntos
# Out:
# False

# %%
a = frozenset({1,2,3}) #convierte inmutable a un conjunto

# %% [markdown]
# #### 6.6. Diccionarios

# %% [markdown]
# {index ó keys: values}  =  {indices ó llaves: valores}

# %%
# los valores de los significantes(values) pueden ser listas o tuplas, e incluso diccionarios
diction ={'a':'armadillo','b':'burro','c':'cabra'}
diction['a'] # imprime el value del index 'a'
# Out:
# 'armadillo'

# %%
diction.values() # imprime(armadillo,burro,...)
# Out:
# dict_values(['armadillo', 'burro', 'cabra'])

# %%
diction.keys() # imprime(a,b,c)
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
list(diction.values()).index('cabra') # busca el indice de la cadena "cabra"
# Out:
# 2

# %%
list(diction.keys())[list(diction.values()).index('cabra')] # busca la llave de la cadena "cabra"
# Out:
# 'c'

# %%
diction['d'] = 'delfin' # crea o edita un elemento
diction
# Out:
# {'a': 'armadillo', 'b': 'burro', 'c': 'cabra', 'd': 'delfin'}

# %%
# busca en index's y si no lo encuentra imprime: "no existe ese valor"
diction.get("b","no existe ese valor")
# Out:
# 'burro'

# %% [markdown]
# Creación de tuplas dentro de una lista

# %%
diction.items()
# Out:
# dict_items([('a', 'armadillo'), ('b', 'burro'), ('c', 'cabra'), ('d', 'delfin')])

# %%
len(diction) # cuenta cuantos index hay en el diccionario
# Out:
# 4

# %%
'a' in diction # verifica si un index esta presente
# Out:
# True

# %%
'armadillo' in diction.values() # si un value esta presente
# Out:
# True

# %%
'burro' is diction['b'] # true, mismo ID
# Out:
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /tmp/ipython-input-291104522.py:1: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   'burro' is diction['b'] # true, mismo ID
# True

# %%
'burro' == diction['b'] # true, mismo ID
# Out:
# True

# %%
'burro'in diction['b'] # true , mismo ID
# Out:
# True

# %%
for animal in diction:
    # print(animal) # a,b,c
    # print(diction[animal]) # armadillo,burro,..
    if diction[animal] == 'burro':
        print(animal)
# Out:
# b

# %%
diction.clear() #borra todos lo elementos
diction
# Out:
# {}

# %% [markdown]
# ### 7. Funciones

# %% [markdown]
# ####  7.1. Break (ruptura)

# %%
# Salga del bucle cuando sea "banana":x
fruits = ["apple", "banana", "cherry", "pear"]
for x in fruits:
  print(x)
  if x == "banana":
    break
# Out:
# apple
# banana

# %%
# Salir del bucle cuando es "plátano", Pero esta vez el descanso llega antes de la impresión:x
fruits = ["apple", "banana", "cherry", "pear"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple

# %% [markdown]
# ####  7.2. Continue

# %%
# Con la declaración continue podemos detener el iteración actual del bucle y continúe con la siguiente
fruits = ["apple", "banana", "cherry", "pear"]
for x in fruits:
  if x == "banana": # No imprime plátano
    continue
  print(x)
# Out:
# apple
# cherry
# pear

# %% [markdown]
# #### 7.3. Range

# %%
# Devuelve una secuencia de números, comenzando desde 0 por defecto, e incrementos por 1 (por defecto), y termina en un número especificado.
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# Incremente la secuencia con 3 (el valor predeterminado es 1):
for x in range(2, 20, 3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17

# %% [markdown]
# #### 7.4. Pass

# %%
# Los bucles no pueden estar vacíos, pero si para Alguna razón tiene un bucle sin contenido, poner en la declaración para evitar obtener un error.
for x in [0, 1, 2]:
  pass

# %% [markdown]
# #### 7.5. Def (funciones)

# %%
def sumar1(x,y): # x & y son los argumentos de entrada
  return(x+y)
resultado=sumar1(3,4)
print(resultado)
type(resultado)
# Out:
# 7
# int

# %% [markdown]
# Sin *Return*

# %%
def sumar1(x,y): # x & y son los argumentos de entrada
  print(x+y)
resultado=sumar1(3,4)
print(resultado)
type(resultado)  # NoneType es un tipo de datos que representa la ausencia de valor
# Out:
# 7
# None
# NoneType

# %% [markdown]
# Argumentos por default

# %%
def sumar(x,y=1): # y toma un valor por default
    suma=x+y
    return (suma,x,y)
sumar(3)
# Out:
# (4, 3, 1)

# %% [markdown]
# Una función que lee una lista de elementos numéricos.

# %%
def crearLista(n): # n es argumento de entrada para el número de elementos en la lista
    L =[]
    #n = int(input("ingrese el número de elementos: "))
    for e in range(n):
        print("ingrese el ",e+1," elemento:")
        elem = float(input())
        L.append(elem)
    return (L)
A = crearLista(3) # A toma el valor de la lista creada
A
# Out:
# ingrese el  1  elemento:
# 1
# ingrese el  2  elemento:
# 2
# ingrese el  3  elemento:
# 4
# [1.0, 2.0, 4.0]

# %%
crearLista(3)[0]
# Out:
# ingrese el  1  elemento:
# 5
# ingrese el  2  elemento:
# 7
# ingrese el  3  elemento:
# 9
# 5.0

# %% [markdown]
# De una lista retorna el valor de la media

# %%
def media(lista):
    n = len(lista)
    media = sum(lista)/n
    return media
media([0,1,2,3,4])
# Out:
# 2.0

# %% [markdown]
# Composicion de funciones

# %%
media(crearLista(4)) # f(g(x))
# Out:
# ingrese el  1  elemento:
# 2
# ingrese el  2  elemento:
# 4
# ingrese el  3  elemento:
# 6
# ingrese el  4  elemento:
# 8
# 5.0

# %%
def aprobado(nota):
    return nota>=10.5
aprobado(media(crearLista(4))) # h(f(g(x)))
# Out:
# ingrese el  1  elemento:
# 13
# ingrese el  2  elemento:
# 17
# ingrese el  3  elemento:
# 4
# ingrese el  4  elemento:
# 5
# False

# %% [markdown]
# #### 7.6. Lambda

# %%
x = lambda a : a + 10
x(5)
# Out:
# 15

# %%
# Pueden tomar cualquier número de argumentos
x = lambda a, b, c : a + b + c
x(5, 6, 2)
# Out:
# 13

# %% [markdown]
# Función anónima durante un corto período de tiempo

# %%
def myfunc(n):
  return lambda a : a * n

# %%
mydoubler = myfunc(2) # Duplica el número
mydoubler(11)
# Out:
# 22

# %%
mytripler = myfunc(3) # Triplica el número
mytripler(11)
# Out:
# 33

# %% [markdown]
# ### 8. Clases y objetos

# %% [markdown]
# #### 8.1. Clases

# %%
class MyClass: # clase denominada MyClass
  x = 5        # con una propiedad denominada x

# %% [markdown]
# #### 8.2. Objetos

# %%
p1 = MyClass() # objeto denominado p1
p1.x
# Out:
# 5

# %% [markdown]
# La función *__ init __()*

# %%
class persona:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = persona("John", 36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %%
print(p1)
# Out:
# <__main__.persona object at 0x7e57be7538f0>

# %% [markdown]
# La función *__ str __()*

# %%
class persona:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name}({self.age})"

p2 = persona("John", 36)
print(p2)
p2
# Out:
# John(36)

# %% [markdown]
# #### 8.3. Métodos de Objetos

# %%
class persona:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)

p1 = persona("John", 36)
p1.myfunc()
# Out:
# Hello my name is John

# %% [markdown]
# El parámetro *self*
#
# Es una referencia a la instancia actual de la clase, y se utiliza para acceder a las variables que pertenecen a la clase.self

# %%
class persona:
  def __init__(mysillyobject, name, age): # mysillyobject en lugar de self
    mysillyobject.name = name
    mysillyobject.age = age

  def myfunc(abc):                        # abc en lugar de self
    print("Hello my name is " + abc.name)

p1 = persona("John", 36)
p1.myfunc()
# Out:
# Hello my name is John

# %% [markdown]
# Modificar propiedades de objeto

# %%
p1.age = 40

# %% [markdown]
# Eliminar propiedades de objeto

# %%
del p1.age

# %% [markdown]
# Eliminar objetos

# %%
del p1

# %% [markdown]
# La declaración de aprobación

# %%
class Person:
  pass      # para evitar obtener un error, en caso la clase este vacía
